# %%
import numpy as np
import scipy
import math
from scipy.integrate import odeint

# %%
np.trapz([1,2,3])
# Out:
# 4.0

# %%
u=29 #молярная масса воздуха
T=300 #температура
L=100000 #длина 
d=1 #диаметр трубы
S=math.pi*(d/2.0)**2 #площадь поперечного сечения трубы
P1=10000 #давление в стационаре
G0=0.01 #расход в стационаре
lamda=0.05 #сопротивление в трубе
R=8.3144 #газовая постоянная
A=(lamda*R*T)/(2*d*u) #введенные константы
C1=T*R/u
F0=P1*S #начальная сила в стационаре

# %%
def Psr2(p1,c2):
    return (2/3)*((pow(p1,3)-pow((pow(p1,2)-c2*1),3/2)))/(c2)
Psr2(1,1)
# Out:
# 0.6666666666666666

# %%
#Строим вектора, необходимые для передачи в функцию решатель
X=[0,L] #изменение переменой х
Xp=400 #число разбиений при вычислении
tmax=40000
t=[0, tmax] #изменение временной переменной
tp=200 #число разбиений по времени

# %%
#def rhs(x,t,u,ux,uxx):
#    return list(-C1*ux1, (A*(pow(u1,2)/u0))-ux0)

# %%
def init(x):
    return [(((F0**2)-2*A*(G0**2)*x)**(1/2.0)),
           G0]

# %%
def bc_func(t):
    result=[[init(0.0)[0],init(L)[0],"D"],
            [0.0,0.0,"D"]]
    return result

# %%
print(bc_func(t))
# Out:
# [[7853.981633974483, 7853.978896157746, 'D'], [0.0, 0.0, 'D']]

# %%
print(init(L))
# Out:
# [7853.978896157746, 0.01]

# %%
#ничерта не получается без формул Gdx и Fdx
#У Gdx известны только граничные точки
#Зависимость от t какая-то мнимая. В системе уравнений вообще не присутствует t.
#Походу, зависимость только от x(0,L)??
def model1(z,t,x):
    F = z[0]
    G = z[1]
    Fdt = -Gdx*C1
    Gdt = (A*(G**2)/F)-Fdx-(C1*G/F)*Gdx 
    zdt = [Fdt,Gdt]
    
    
    return zdt

# %%
def model(z,t,x):
    F = z[0]
    G = z[1]
    Fdt = -G*C1
    Gdt = (A*(G**2)/F) - ((F**2)-A*x*G**2)**(1/2) - (C1*G/F)*G   
    
    zdt = [Fdt,Gdt]  
    
    return zdt

# %%
z0 = ((F0**2)-A*X[0]*G0**2)**(1/2)

u = np.linspace(0,L,Xp)
 
#tt=np.linspace(1, tmax, tp)
#print(tt)
for i in range(1,tmax,tp):
    tspan = [t[i-1],t[i]]
    z = odeint(model,z0,tspan,tuple(u))
    z0=z[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-0ad3c9f80fe5> in <module>
#       7 for i in range(1,tmax,tp):
#       8     tspan = [t[i-1],t[i]]
# ----> 9     z = odeint(model,z0,tspan,tuple(u))
#      10     z0=z[1]
#
# c:\python\lib\site-packages\scipy\integrate\odepack.py in odeint(func, y0, t, args, Dfun, col_deriv, full_output, ml, mu, rtol, atol, tcrit, h0, hmax, hmin, ixpr, mxstep, mxhnil, mxordn, mxords, printmessg, tfirst)
#     242                              full_output, rtol, atol, tcrit, h0, hmax, hmin,
#     243                              ixpr, mxstep, mxhnil, mxordn, mxords,
# --> 244                              int(bool(tfirst)))
#     245     if output[-1] < 0:
#     246         warning_msg = _msgs[output[-1]] + " Run with full_output = 1 to get quantitative information."
#
# TypeError: model() takes 3 positional arguments but 402 were given
